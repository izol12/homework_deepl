# %%
import matplotlib.pyplot as plt
from scipy import signal
from scipy.io import wavfile

i

sample_rate, samples = wavfile.read('clesmer.wav')
samples0 = samples[:,1]
frequencies, times, spectrogram = signal.spectrogram(samples0, sample_rate)


plt.specgram(samples[:, 1], Fs=sample_rate)
plt.show()
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
